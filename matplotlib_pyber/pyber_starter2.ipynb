# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)
# Combine the data into a single dataset

fares = ride_data.groupby('city')['fare'].sum()
rides = ride_data.groupby('city')['city'].count()
avg = fares / rides
merge_table = pd.merge(city_data, pd.DataFrame({'avgfare':avg, 'rides':rides, 'fares':fares}).reset_index(), on="city")

# Display the data table for preview
#city_data.head()
merge_table.head(30)
# Out:
#                     city  driver_count   type    avgfare  rides    fares
# 0            Richardfort            38  Urban  22.373214     28   626.45
# 1           Williamsstad            59  Urban  24.362174     23   560.33
# 2            Port Angela            67  Urban  23.836842     19   452.90
# 3             Rodneyfort            34  Urban  28.616957     23   658.19
# 4            West Robert            39  Urban  25.123871     31   778.84
# 5           West Anthony            70  Urban  24.736667     30   742.10
# 6            West Angela            48  Urban  25.990000     39  1013.61
# 7          Martinezhaven            25  Urban  22.651250     24   543.63
# 8              Karenberg            22  Urban  26.340000     17   447.78
# 9            Barajasview            26  Urban  25.332273     22   557.31
# 10            Robertport            12  Urban  23.060500     20   461.21
# 11          Joneschester            39  Urban  22.289600     25   557.24
# ...

# %%
colors = {"Urban":"coral", "Suburban":"skyblue", "Rural":"yellow"}

# x, Urban
x_urban = merge_table[merge_table.type=='Urban'] ['fares']
#print(x_urban)

y_urban = merge_table[merge_table.type=='Urban'] ['avgfare']
#print(x_urban)

plt.scatter(x_urban, y_urban, marker="o", facecolors="coral", edgecolors="blue",
            s=x_urban, alpha=0.75)


# x, Suburban
x_Suburban = merge_table[merge_table.type=='Suburban'] ['fares']
#print(x_urban)

y_Suburban = merge_table[merge_table.type=='Suburban'] ['avgfare']
#print(x_urban)

plt.scatter(x_Suburban, y_Suburban, marker="o", facecolors="skyblue", edgecolors="blue",
            s=x_Suburban, alpha=0.75)



# x, Rural
x_Rural = merge_table[merge_table.type=='Rural'] ['fares']
#print(x_urban)

y_Rural = merge_table[merge_table.type=='Rural'] ['avgfare']
#print(x_urban)

plt.scatter(x_Rural, y_Rural, marker="o", facecolors="yellow", edgecolors="blue",
            s=x_Rural, alpha=0.75)

# Set a grid on the plot
plt.grid()

# Incorporate the other graph properties
plt.title("Pyber Ride Sharing")
plt.xlabel("Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")


#create legend
plt.legend(loc= "best")

# Save an image of the chart and print to screen
plt.savefig("pyberridesharing.png")
plt.show()

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate a text label regarding circle size

# Save Figure

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
type_df = merge_table.groupby(["type"]) 
total_rides= type_df["city"].count()


# Build Pie Chart
labels = ["Rural", "Suburban", "Urban"]
# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [total_rides[0], total_rides[1], total_rides[2]]

# The colors of each section of the pie chart
colors = ["green", "coral", "blue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0.1)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.title("% Total Rides (City)")

# Save Figure
plt.savefig("rides_city.png")

# Show Figure
plt.show()

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
type_df = merge_table.groupby(["type"]) 
total_driver = type_df["driver_count"].sum()
print(total_driver[0])
print(total_driver)


# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [total_driver[0], total_driver[1], total_driver[2]]

# The colors of each section of the pie chart
colors = ["green", "coral", "blue"]

# Tells matplotlib 
explode = (0, 0, 0.1)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=120)

plt.title("Total Rides (City)")

# Save Figure
plt.savefig("Total_Rides.png")


plt.show()
# Out:
# 78
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
type_df = merge_table.groupby(["type"]) 
total_driver = type_df["driver_count"].sum()
print(total_driver[0])
print(total_driver)

# Build Pie Charts

# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [total_driver[0], total_driver[1], total_driver[2]]

# The colors of each section of the pie chart
colors = ["green", "coral", "blue"]

# Tells matplotlib to seperate 
explode = (0, 0, 0.1)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=120)

plt.title("Driver Count (City)")

# Save Figure
plt.savefig("Driver_Count.png")

# Show Figure
plt.show()
# Out:
# 78
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
# Show Figure
plt.show()
